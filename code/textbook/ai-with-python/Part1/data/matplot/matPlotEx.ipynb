# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
#shows plot in Notebbok
# %matplotlib inline

# %%
#create random time series
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))

# %%
ts = ts.cumsum()

ts.plot()
# Out:
# <Axes: >
